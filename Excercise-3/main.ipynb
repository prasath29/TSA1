# %% [markdown]
# Stationary Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
series=pd.read_csv('daily-total-female-births.csv',header=0,index_col=0)
series.head()
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %%
series.plot(figsize=(20,10))
plt.figure(figsize=(5,5))
plt.show()

# %%
series.hist(figsize=(20,10),grid=False)
plt.show()

# %%
series.mean()
# Out:
# Births    41.980822
# dtype: float64

# %%
X = series.values
split = round(len(X) / 2)
X1, X2 = X[0:split], X[split:]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=39.763736, mean2=44.185792
# variance1=49.213410, variance2=48.708651

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result=adfuller(X)
print('ADF Statistics: %f'%result[0])
print('p-value: %f'%result[1])
print('Critical Values: ')
for key,value in result[4].items():
    print('\t%s: %.3f'%(key, value))
# Out:
# ADF Statistics: -4.808291
# p-value: 0.000052
# Critical Values:
# 	1%: -3.449
# 	5%: -2.870
# 	10%: -2.571

# %% [markdown]
# Upto above is Enough no need to write the below code

# %% [markdown]
# Non-Stationary Time series Data

# %%
series2 = pd.read_csv('airline-passengers.csv', index_col=0)
series2.head()
# Out:
#          Passengers
# Month
# 1949-01         112
# 1949-02         118
# 1949-03         132
# 1949-04         129
# 1949-05         121

# %%
series2.plot(figsize=(20,10))
plt.show()

# %%
Y=series2.values
split2=round(len(Y)/2)
Y1, Y2 = Y[0:split2], Y[split2:]
Y_mean1, Y_mean2 = Y1.mean(), Y2.mean()
y_var1, y_var2 = Y1.var(), Y2.var()
print('mean1=%f, mean2=%f'%(Y_mean1, Y_mean2))
print('variance1=%f, variance2=%f'%(y_var1,y_var2))
# Out:
# mean1=182.902778, mean2=377.694444
# variance1=2244.087770, variance2=7367.962191

# %%
y=np.log(Y)
plt.hist(y)
plt.show()
plt.plot(y)
plt.show()

# %%
result1=adfuller(Y)
print('ADF Statistic: %f' % result1[0])
print('p-value: %f' % result1[1])
print('Critical Values:')
for key, value in result1[4].items():
 print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: 0.815369
# p-value: 0.991880
# Critical Values:
# 	1%: -3.482
# 	5%: -2.884
# 	10%: -2.579
