# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from sklearn.linear_model import LinearRegression
import numpy
# Out:
# C:\Users\Exam\AppData\Local\Temp\ipykernel_20200\910703114.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
def parser(x):
    return datetime.strptime('190'+x, '%Y-%m')

# %%
series = read_csv('shampoo_sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True,date_parser=parser)
X = series.values
diff = list()
for i in range(1, len(X)):
    value = X[i] - X[i - 1]
diff.append(value)
print(diff)
# Out:
# [65.60000000000002]
# C:\Users\Exam\AppData\Local\Temp\ipykernel_20200\44738748.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = read_csv('shampoo_sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True,date_parser=parser)

# %%
X = [i for i in range(0, len(series))]
X = numpy.reshape(X, (len(X), 1))
y = series.values
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
trend = model.predict(X)

# %%
pyplot.plot(y)
pyplot.plot(trend)
pyplot.show()

# %%
detrended = [y[i]-trend[i] for i in range(0, len(series))]

# %%
pyplot.plot(detrended)
pyplot.show()
