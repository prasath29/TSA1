# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("stock.csv",parse_dates=True, index_col="Date")
df.head()
# Out:
#             Unnamed   Open   High    Low  Close    Volume  Name
# Date
# 2006-01-03        0  39.69  41.22  38.79  40.91  24232729  AABA
# 2006-01-04        0  41.22  41.90  40.77  40.97  20553479  AABA
# 2006-01-05        0  40.93  41.73  40.85  41.53  12829610  AABA
# 2006-01-06        0  42.88  43.57  42.80  43.21  29422828  AABA
# 2006-01-09        0  43.10  43.66  42.82  43.42  16268338  AABA

# %%
df.drop(columns='Unnamed')
# Out:
#              Open   High    Low  Close    Volume  Name
# Date
# 2006-01-03  39.69  41.22  38.79  40.91  24232729  AABA
# 2006-01-04  41.22  41.90  40.77  40.97  20553479  AABA
# 2006-01-05  40.93  41.73  40.85  41.53  12829610  AABA
# 2006-01-06  42.88  43.57  42.80  43.21  29422828  AABA
# 2006-01-09  43.10  43.66  42.82  43.42  16268338  AABA
# ...           ...    ...    ...    ...       ...   ...
# 2017-12-22  71.42  71.87  71.22  71.58  10979165  AABA
# 2017-12-26  70.94  71.39  69.63  69.86   8542802  AABA
# 2017-12-27  69.77  70.49  69.69  70.06   6345124  AABA
# 2017-12-28  70.12  70.32  69.51  69.82   7556877  AABA
# 2017-12-29  69.79  70.13  69.43  69.85   6613070  AABA
#
# [3019 rows x 6 columns]

# %%
df['Volume'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df.plot(subplots=True, figsize=(10, 12))
# Out:
# array([<AxesSubplot: xlabel='Date'>, <AxesSubplot: xlabel='Date'>,
#        <AxesSubplot: xlabel='Date'>, <AxesSubplot: xlabel='Date'>,
#        <AxesSubplot: xlabel='Date'>, <AxesSubplot: xlabel='Date'>],
#       dtype=object)

# %%
df_month = df.resample("M").mean()


fig, ax = plt.subplots(figsize=(10, 6))


ax.bar(df_month['2016':].index,
	df_month.loc['2016':, "Volume"],
	width=25, align='center')
# Out:
# C:\Users\Exam\AppData\Local\Temp\ipykernel_14352\1326322086.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_month = df.resample("M").mean()
# <BarContainer object of 24 artists>

# %%
df.Low.diff(2).plot(figsize=(10, 6))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df.High.diff(2).plot(figsize=(10, 6))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df['Change'] = df.Close.div(df.Close.shift())
df['Change'].plot(figsize=(10, 8), fontsize=16)
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df['2017']['Change'].plot(figsize=(10, 6))
# Out:
# C:\Users\Exam\AppData\Local\Temp\ipykernel_14352\539075465.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2017']['Change'].plot(figsize=(10, 6))
# <AxesSubplot: xlabel='Date'>
